# %%
#Erez Sarousi
#Professor Werner
#DSC550 Data Mining
#Bellevue University
#3/30/2021

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
db = pd.read_csv('database.csv')
df = db.sample(n=1000)
df.head()
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 8045   06/24/1986  03:11:31    -4.448    143.943  Earthquake  102.3
# 6283   09/03/1982  23:39:39   -15.296   -173.089  Earthquake   33.0
# 16497  10/25/2003  12:41:35    38.400    100.951  Earthquake   10.0
# 7683   09/10/1985  04:07:47    -6.394    149.733  Earthquake   10.0
# 16274  05/24/2003  00:30:47   -14.668    -71.514  Earthquake  143.8
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 8045           NaN                     NaN        7.2             MW  ...
# 6283           NaN                     NaN        6.3             MW  ...
# 16497          NaN                   493.0        5.8            MWB  ...
# 7683           NaN                     NaN        6.5             MW  ...
# 16274          NaN                   258.0        5.6            MWB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
fig_dims = (9, 7)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x='Magnitude', data=df, ax=ax)

# %%
fig_dims = (9, 7)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x='Magnitude', data=df, ax=ax)

# %%
df.plot.pie(y='Magnitude')

# %%
# For this week’s assignment, I found a dataset that focuses on earthquakes. Specifically, I wanted to see the distribution
# of the magnitude of the earthquakes when they occur and saw the frequency of each magnitude frequency.

# I decided to spend that assignment trying out the different visualization packages. I even thought it was important to
# check on the different packages because they all do different things. Furthermore, they all have a different approach to
# their syntax. After collaborating with professors, tutors and colleagues, I have found that much like ice cream flavors,
# each of them have their preference to which package they like to use for their graphics needs. I personally noticed that
# I am a big fan of Seaborn.

# Beyond the type of graphics and focusing a bit more on the types of charts used, it becomes glaringly obvious that not
# all charts are appropriate for all situations. For the different graphical representations, I’ve used a frequency line
# chart, a box and whisker plot and a pie chart -- in the order of what makes most sense to least sense.

# Using a frequency line graph makes most sense because it’s cleanest and it easily shows exactly how much frequency there
# is. Beyond the different lines on the X axis, the colors help to differentiate the different categories.

# Next, there’s the box and whisker chart. This is helpful in the sense that the box displays where the bulk of the entries
# are. The whiskers in the plots show the outliers, so that’s helpful. However, what leaves room for improvement is the
# fact that you can’t find the different categories. It’s not easy to see the amounts for each category. Box and whisker
# plots are much better suited for single-category items and having more plots for each category.

# Finally, the least appropriate chart for this plot was the pie chart. What makes this so inappropriate here was the
# messiness. At first, I thought that the lines outside of the plot were scribbles. It took me a moment to realize that
# they were captions. Furthermore, there were far too many categories. It seems to me that three or four categories are the
# most amount of categories for a pie chart. This helps increase clarity and thus, the effectiveness of the graph.
